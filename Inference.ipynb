# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler  
import os
import itertools
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import torch.nn.functional as F
from tqdm import tqdm, tqdm_notebook
import torch.nn as nn
from torch.autograd import Variable as V
from torch.autograd import grad
from torch.utils.data import DataLoader,Dataset, TensorDataset
seed = 42
import torch
from torch.nn import Linear, ReLU, MSELoss, Sequential, Conv1d, MaxPool1d, Module, Softmax, BatchNorm1d, Dropout
import torchvision.models as models
import torch.optim as optim

from Model import MultiTask
from multi_output_data_prep import MultiOutputDataset
from losses import XSigmoidLoss, LogCoshLoss, AlgebraicLoss

# %%
X = np.load('X_inference.npy')
data = torch.tensor(X, dtype=torch.float)

model = MultiTask()
    PATH = "Saved_Trained_Model.pth"
    model.load_state_dict(torch.load(PATH))

    model.eval()
    with torch.no_grad():
        output1, output2, output3, output4 = model(data)
    
    print('Task 1 Predictions:', output1)
    print('Task 2 Predictions:', output2)
    print('Task 3 Predictions:', output3)
    print('Task 4 Predictions:', output4)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler  
import os
import itertools
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import torch.nn.functional as F
from tqdm import tqdm, tqdm_notebook
import torch.nn as nn
from torch.autograd import Variable as V
from torch.autograd import grad
from torch.utils.data import DataLoader,Dataset, TensorDataset
seed = 42
import torch
from torch.nn import Linear, ReLU, MSELoss, Sequential, Conv1d, MaxPool1d, Module, Softmax, BatchNorm1d, Dropout
import torchvision.models as models
import torch.optim as optim

from Model import MultiTask
from multi_output_data_prep import MultiOutputDataset
from losses import XSigmoidLoss, LogCoshLoss, AlgebraicLoss

# %%
X = np.load('X_inference.npy')
Y = np.load('Y_inference.npy')

y1_test = Y[:,0]
y2_test = Y[:,1]
y3_test = Y[:,2]
y4_test = Y[:,3]

test_loader = DataLoader(dataset=MultiOutputDataset(X, y1_test, y2_test, y3_test, y4_test), shuffle=False, batch_size = 1)

dataiter = iter(test_loader)
data, label1, label2, label3,label4 = dataiter.next()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

model = MultiTask()

# Load the saved model checkpoint
PATH = "Saved_Trained_Model.pth"
model.load_state_dict(torch.load(PATH))

model.eval()

with torch.no_grad():
    output1, output2, output3, output4 = model(data)
    
    # Print the predicted values for the first sample in the subset
    print('Task 1 Predictions:', output1)
    print('Task 2 Predictions:', output2)
    print('Task 3 Predictions:', output3)
    print('Task 4 Predictions:', output4)

# %%
X = np.load('X_inference.npy')
Y = np.load('Y_inference.npy')

y1_test = Y[:,0]
y2_test = Y[:,1]
y3_test = Y[:,2]
y4_test = Y[:,3]

test_loader = DataLoader(dataset=MultiOutputDataset(X, y1_test, y2_test, y3_test, y4_test), shuffle=False, batch_size = 1)

dataiter = iter(test_loader)
data, label1, label2, label3,label4 = dataiter.next()

model = MultiTask()
PATH = "Saved_Trained_Model.pth"
model.load_state_dict(torch.load(PATH))

model.eval()
for data, target1, target2, target3, target4  in test_loader:
    output1, output2, output3, output4 = model(data)
